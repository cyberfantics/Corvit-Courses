# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.shape
# Out:
# (891, 12)
# (891, 12)

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#        PassengerId    Survived      Pclass         Age       SibSp  \
# ...

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# # One Method To Get Same DataTypes In Our Data

# %%
df[df.dtypes[df.dtypes=='int64'].index] #This Line show us only columns which contain int type data
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index] #This line show us only columns having object/string types data
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %% [markdown]
# # Check columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %% [markdown]
# # Slicling

# %%
df[['Ticket']][5:10]
# Out:
#    Ticket
# 5  330877
# 6   17463
# 7  349909
# 8  347742
# 9  237736
#    Ticket
# 5  330877
# 6   17463
# 7  349909
# 8  347742
# 9  237736

# %%
df[['Ticket']][1:15:2]
# Out:
#       Ticket
# 1   PC 17599
# 3     113803
# 5     330877
# 7     349909
# 9     237736
# 11    113783
# 13    347082
#       Ticket
# 1   PC 17599
# 3     113803
# 5     330877
# 7     349909
# 9     237736
# 11    113783
# 13    347082

# %%
df[['Ticket','Cabin']]
# Out:
#                Ticket Cabin
# 0           A/5 21171   NaN
# 1            PC 17599   C85
# 2    STON/O2. 3101282   NaN
# 3              113803  C123
# 4              373450   NaN
# ..                ...   ...
# 886            211536   NaN
# 887            112053   B42
# 888        W./C. 6607   NaN
# 889            111369  C148
# 890            370376   NaN
#
# [891 rows x 2 columns]
#                Ticket Cabin
# 0           A/5 21171   NaN
# 1            PC 17599   C85
# 2    STON/O2. 3101282   NaN
# 3              113803  C123
# 4              373450   NaN
# ..                ...   ...
# 886            211536   NaN
# 887            112053   B42
# 888        W./C. 6607   NaN
# 889            111369  C148
# 890            370376   NaN
#
# [891 rows x 2 columns]

# %%
df[['Ticket','Cabin']][0:16:2]
# Out:
#               Ticket Cabin
# 0          A/5 21171   NaN
# 2   STON/O2. 3101282   NaN
# 4             373450   NaN
# 6              17463   E46
# 8             347742   NaN
# 10           PP 9549    G6
# 12         A/5. 2151   NaN
# 14            350406   NaN
#               Ticket Cabin
# 0          A/5 21171   NaN
# 2   STON/O2. 3101282   NaN
# 4             373450   NaN
# 6              17463   E46
# 8             347742   NaN
# 10           PP 9549    G6
# 12         A/5. 2151   NaN
# 14            350406   NaN

# %%
df["Ticket"]
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
a = df['Ticket'][0:7]

# %%
type(a)
# Out:
# pandas.core.series.Series
# pandas.core.series.Series

# %%
b = df[['Ticket']]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame
# pandas.core.frame.DataFrame

# %%
pd.Series(a,index=[1,2,3,4,5,6])
# Out:
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# 5              330877
# 6               17463
# Name: Ticket, dtype: object
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# 5              330877
# 6               17463
# Name: Ticket, dtype: object

# %%
pd.Series(a,index=['a','K','As','Na','Kh'])
# Out:
# a     NaN
# K     NaN
# As    NaN
# Na    NaN
# Kh    NaN
# Name: Ticket, dtype: object
# a     NaN
# K     NaN
# As    NaN
# Na    NaN
# Kh    NaN
# Name: Ticket, dtype: object

# %%
pd.Series(list(a),index=['as','na','K','ha','d','Ij','A'])
# Out:
# as           A/5 21171
# na            PC 17599
# K     STON/O2. 3101282
# ha              113803
# d               373450
# Ij              330877
# A                17463
# dtype: object
# as           A/5 21171
# na            PC 17599
# K     STON/O2. 3101282
# ha              113803
# d               373450
# Ij              330877
# A                17463
# dtype: object

# %% [markdown]
# # Concatination

# %%
b1 = pd.Series([13,24,5.6,36,45],index=[1,2,3,4,5])

# %%
b2 = pd.Series([34,54,23,5,7],index = [12,3,4,5,6])

# %%
pd.concat([b1,b2])
# Out:
# 1     13.0
# 2     24.0
# 3      5.6
# 4     36.0
# 5     45.0
# 12    34.0
# 3     54.0
# 4     23.0
# 5      5.0
# 6      7.0
# dtype: float64
# 1     13.0
# 2     24.0
# 3      5.6
# 4     36.0
# 5     45.0
# 12    34.0
# 3     54.0
# 4     23.0
# 5      5.0
# 6      7.0
# dtype: float64

# %%
b3 = pd.concat([b1,b2])

# %%
b3[1]
# Out:
# 13.0
# 13.0

# %%
b2[3]
# Out:
# 54
# 54

# %%
b3[3]
# Out:
# 3     5.6
# 3    54.0
# dtype: float64
# 3     5.6
# 3    54.0
# dtype: float64

# %%
b3[12]
# Out:
# 34.0
# 34.0

# %%
b3[4]
# Out:
# 4    36.0
# 4    23.0
# dtype: float64
# 4    36.0
# 4    23.0
# dtype: float64

# %%
m4 = b1*b2

# %%
m4
# Out:
# 1       NaN
# 2       NaN
# 3     302.4
# 4     828.0
# 5     225.0
# 6       NaN
# 12      NaN
# dtype: float64
# 1       NaN
# 2       NaN
# 3     302.4
# 4     828.0
# 5     225.0
# 6       NaN
# 12      NaN
# dtype: float64

# %%
a5 = b1+b2

# %%
a5
# Out:
# 1      NaN
# 2      NaN
# 3     59.6
# 4     59.0
# 5     50.0
# 6      NaN
# 12     NaN
# dtype: float64
# 1      NaN
# 2      NaN
# 3     59.6
# 4     59.0
# 5     50.0
# 6      NaN
# 12     NaN
# dtype: float64

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.drop('Parch')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6676\3237953322.py in <module>
# ----> 1 df.drop('Parch')
#
# D:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
# ...

# %% [markdown]
# # Delete a column or Row

# %%
df.drop('Parch',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# ...

# %%
df.drop('Parch',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %% [markdown]
# ### Inplace is used to permenantly delete data

# %%
df.drop(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
# ...

# %%
df.drop(3,inplace=True)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# ...

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 4            373450   8.0500   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 4            5         0       3
#
# ...

# %% [markdown]
# ### That's how we delete data from columns and rows

# %%
df.insert(loc=3,column="Food",value=0)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     0
# 1            2         1       1     0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     0
# 1            2         1       1     0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     0
# 1            2         1       1     0
# 2            3         1       3     0
# 4            5         0       3     0
# 5            6         0       3     0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
# ...

# %%
df.drop("Food",axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#       Ticket  Fare Cabin Embarked
# 0  A/5 21171  7.25   NaN        S
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#       Ticket  Fare Cabin Embarked
# 0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # Set Index

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 5                   0       3
# 6                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...                                                        ...     ...   ...
# ...

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#       Ticket  Fare Cabin Embarked
# 0  A/5 21171  7.25   NaN        S
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#       Ticket  Fare Cabin Embarked
# 0  A/5 21171  7.25   NaN        S

# %%
df.set_index('PassengerId',inplace=True)

# %%
df.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#                 Ticket  Fare Cabin Embarked
# PassengerId
# 1            A/5 21171  7.25   NaN        S
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#                 Ticket  Fare Cabin Embarked
# PassengerId
# 1            A/5 21171  7.25   NaN        S

# %% [markdown]
# # Reset Index

# %%
df.reset_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              5         0       3
# 4              6         0       3
# ..           ...       ...     ...
# 885          887         0       2
# 886          888         1       1
# 887          889         0       3
# 888          890         1       1
# 889          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#                 Ticket  Fare Cabin Embarked
# PassengerId
# 1            A/5 21171  7.25   NaN        S
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#                 Ticket  Fare Cabin Embarked
# PassengerId
# 1            A/5 21171  7.25   NaN        S

# %% [markdown]
# # Dataframe through dictionary

# %%
data = {
    'key1':[1,2,5,43,5,6],
    'key2':['a','b','f','c','r','d'],
    'key3':[5,46,7,8,5,5]
}

# %%
pd.DataFrame(data)
# Out:
#    key1 key2  key3
# 0     1    a     5
# 1     2    b    46
# 2     5    f     7
# 3    43    c     8
# 4     5    r     5
# 5     6    d     5
#    key1 key2  key3
# 0     1    a     5
# 1     2    b    46
# 2     5    f     7
# 3    43    c     8
# 4     5    r     5
# 5     6    d     5

# %%
data
# Out:
# {'key1': [1, 2, 5, 43, 5, 6],
#  'key2': ['a', 'b', 'f', 'c', 'r', 'd'],
#  'key3': [5, 46, 7, 8, 5, 5]}
# {'key1': [1, 2, 5, 43, 5, 6],
#  'key2': ['a', 'b', 'f', 'c', 'r', 'd'],
#  'key3': [5, 46, 7, 8, 5, 5]}

# %%
data = pd.DataFrame(data)

# %%
data.set_index('key2',inplace=True)

# %%
data.head(2)
# Out:
#       key1  key3
# key2
# a        1     5
# b        2    46
#       key1  key3
# key2
# a        1     5
# b        2    46

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 5                   0       3
# 6                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...                                                        ...     ...   ...
# ...

# %%
df.isna()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Ticket   Fare  \
# PassengerId
# 1               False   False  False  False  False  False   False  False
# 2               False   False  False  False  False  False   False  False
# 3               False   False  False  False  False  False   False  False
# 5               False   False  False  False  False  False   False  False
# 6               False   False  False  False   True  False   False  False
# ...               ...     ...    ...    ...    ...    ...     ...    ...
# 887             False   False  False  False  False  False   False  False
# 888             False   False  False  False  False  False   False  False
# 889             False   False  False  False   True  False   False  False
# 890             False   False  False  False  False  False   False  False
# 891             False   False  False  False  False  False   False  False
#
#              Cabin  Embarked
# PassengerId
# 1             True     False
# ...

# %%
df.dropna()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# 22                  1       2
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# ...                                                        ...     ...   ...
# ...

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 5                   0       3
# 6                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...                                                        ...     ...   ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# 22                  1       2
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # Drop NAN Columns

# %% [markdown]
# ### we load new data because we do permenently changing in previous data

# %%
df.head(1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1  PC 17599  71.2833   C85        C
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1  PC 17599  71.2833   C85        C

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df2.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dropna(axis=1,inplace=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  SibSp  Parch  \
# 0            1         0       3  Braund, Mr. Owen Harris  male      1      0
#
#       Ticket  Fare
# 0  A/5 21171  7.25
#    PassengerId  Survived  Pclass                     Name   Sex  SibSp  Parch  \
# 0            1         0       3  Braund, Mr. Owen Harris  male      1      0
#
#       Ticket  Fare
# 0  A/5 21171  7.25

# %%
df.head(1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1  PC 17599  71.2833   C85        C
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1  PC 17599  71.2833   C85        C

# %% [markdown]
# # Now we load third dataset to filled na

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df3.fillna('Fantics',inplace=True)

# %%
df3.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare    Cabin Embarked
# 0      0  A/5 21171   7.2500  Fantics        S
# 1      0   PC 17599  71.2833      C85        C
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare    Cabin Embarked
# 0      0  A/5 21171   7.2500  Fantics        S
# 1      0   PC 17599  71.2833      C85        C

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1  PC 17599  71.2833   C85        C
# 7                0     17463  51.8625   E46        S
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp    Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
df2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
#
#       Ticket     Fare
# 0  A/5 21171   7.2500
# 1   PC 17599  71.2833
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
#
#       Ticket     Fare
# 0  A/5 21171   7.2500
# 1   PC 17599  71.2833
