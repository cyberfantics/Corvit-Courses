# %% [markdown]
# ## Exploratory Data Anaysis
# Exploratory data analysis is an approch of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visculization methods.

# %% [markdown]
# ## Types of Exploratory Data Analysis
# - Univariate Analysis
# - Bivariate Analysis
# - Multivariate Analysis
# - Time Series Analysis
# - Missing Data Analysis
# - Outlier Analysis

# %%
# import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read Dataset
df = pd.read_excel('US_Superstore_data.xls')

# %%
# Shape of dataset
df.shape
# Out:
# (9994, 21)

# %%
## Check head of dataset
df.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ## Univarient Analysis

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
plt.figure(figsize=(6,2))
sns.countplot(x='Ship Mode', data=df)
plt.title("Count of Ship Mode")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(df['Category'])
plt.title("Count of Title")
plt.show()

# %%
plt.figure(figsize=(30,8))
sns.countplot(x=df['Sub-Category'])
plt.title("Count of Sub Category")
plt.show()

# %% [markdown]
# ## Ship Mode

# %%
## We check how much products are sell in which shiphing mode
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
## Draw viscually
x = df['Ship Mode'].value_counts().index
y = df['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(4,3))
plt.pie(y,labels=x, startangle=60, autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ## Product Category vs Ship Mode

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df['Ship Mode'], hue=df['Category'])
plt.title("Analyze Ship Mode on the Base of Category")
plt.show()

# %%
plt.figure(figsize=(17,3))
sns.countplot(x=df['Sub-Category'], hue=df['Category'])
plt.title("Analyze Sub Category on the base of Category")
plt.show()

# %% [markdown]
# ## Supplies

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df['Segment'])
plt.title('Analyze Coustomer Segment')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df['Segment'], hue=df['Category'])
plt.title("Check our Customer belong to which category Most of time")
plt.show()

# %% [markdown]
# ## Country

# %%
plt.figure(figsize=(4,3))
sns.countplot(x=df['Country']) ## It is unnecessary column in our dataset, as all of our coustomer belongs to only one country
plt.title("Our Coustomer belong to which Country")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.countplot(x='Category', data=df[df['Category']=='Office Supplies'], hue=df['Sub-Category']) 
plt.show()

# %% [markdown]
# ## Make a column for year

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Year'].value_counts()
# Out:
# Order Year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.countplot(x=df['Order Year'])
plt.title("Years in which Orders Placed")
plt.show()

# %% [markdown]
# ## PRofit Per Year

# %%
plt.figure(figsize=(4,3))
sns.barplot(x=df['Order Year'], y = df['Profit'], estimator='sum')
plt.title("Profit on the Base of Year")
plt.show()

# %% [markdown]
# ## State

# %%
df['State'].value_counts()[:5]
# Out:
# State
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: count, dtype: int64
